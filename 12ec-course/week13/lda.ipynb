# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import gensim
from gensim import matutils, corpora
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
url = "https://cssbook.net/d/sotu.csv"
sotu = pd.read_csv(url)
p_obama = (sotu[sotu.President == "Obama"].text.str.split("\n\n").explode())
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
sotu
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       FirstName  President        Date delivery   type       party  \
# 0   Franklin D.  Roosevelt  1945-01-06  written   SOTU  Democratic
# 1   Franklin D.  Roosevelt  1945-01-06   spoken   SOTU  Democratic
# 2      Harry S.     Truman  1946-01-21  written   SOTU  Democratic
# 3      Harry S.     Truman  1947-01-06   spoken   SOTU  Democratic
# 4      Harry S.     Truman  1948-01-07   spoken   SOTU  Democratic
# ..          ...        ...         ...      ...    ...         ...
# 80       Barack      Obama  2015-01-20   spoken   SOTU  Democratic
# 81       Barack      Obama  2016-01-12   spoken   SOTU  Democratic
# ...

# %%
p_obama
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 74    Madam Speaker, Mr. Vice President, Members of ...
# 74    I have come here tonight not only to address t...
# 74    I know that for many Americans watching right ...
# 74    But while our economy may be weakened and our ...
# 74    The weight of this crisis will not determine t...
#                             ...
# 81    I see it in the American who served his time, ...
# 81    I see it in the soldier who gives almost every...
# 81    I see it in the elderly woman who will wait in...
# 81    That's the America I know. That's the country ...
# 81    Thank you. God bless you. God bless the United...
# ...

# %%
cv = TfidfVectorizer(min_df=.01, stop_words="english", ngram_range=(1,2))
dtm = cv.fit_transform(p_obama)
dtm
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <738x740 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15175 stored elements in Compressed Sparse Row format>

# %%
corpus = matutils.Sparse2Corpus(dtm, documents_columns=False)
vocab = corpora.Dictionary()
vocab.id2token = dict(enumerate(cv.get_feature_names()))
vocab.token2id = dict((k, v) for k, v in cv.vocabulary_.items())
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
lda = LdaModel(corpus,id2word=vocab,num_topics=10, random_state=123, alpha="asymmetric")

# same thing as looping over lda.print_topics but with a data frame
pd.DataFrame({f"Topic {n}":[w for (w,tw) in words]
    for (n, words) in 
    lda.show_topics(formatted=False)})
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Topic 0    Topic 1   Topic 2  Topic 3  Topic 4      Topic 5    Topic 6  \
# 0   america        new    people    dream      run       forces      hands
# 1      jobs  education  american    stand   people      housing      tough
# 2  american        tax   america  tonight    money        years  education
# 3    people       work       way      day   street         meet      offer
# 4       new         ve      want   energy  tonight      america       help
# 5     years     people      need  speaker    state      courage   colleges
# 6     world       care      work  chamber   asking        sense  americans
# ...

# %%
topics = pd.DataFrame([dict(lda.get_document_topics(doc, 
          minimum_probability=0.0))
     for doc in corpus])
meta = (sotu.iloc[p_obama.index]
        .drop(columns=["text"])
        .reset_index(drop=True))
tpd = pd.concat([meta, topics], axis=1)
tpd.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   FirstName President        Date delivery   type       party         0  \
# 0    Barack     Obama  2009-02-24   spoken  other  Democratic  0.813210
# 1    Barack     Obama  2009-02-24   spoken  other  Democratic  0.798151
# 2    Barack     Obama  2009-02-24   spoken  other  Democratic  0.853323
# 3    Barack     Obama  2009-02-24   spoken  other  Democratic  0.836797
# 4    Barack     Obama  2009-02-24   spoken  other  Democratic  0.859785
#
#           1         2         3         4         5         6         7  \
# 0  0.036444  0.029214  0.024463  0.021040  0.018462  0.016447  0.014829
# ...

# %%
vis_data = gensimvis.prepare(lda, corpus, vocab)
pyLDAvis.display(vis_data)
# Out:
# /usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1583221396518251093607979354584"></div>
# <script type="text/javascript">
#
# ...
