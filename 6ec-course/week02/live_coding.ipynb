# %%
data = "hi, i'm a string"

# %%
# !ls
# Out:
# .ipynb_checkpoints API_example.ipynb  Untitled.ipynb     my_text_file.txt

# %%
with open('my_text_file.txt', mode = 'w', encoding = 'utf-8') as fo:
    fo.write(data)

# %%
# !cat my_text_file.txt
# Out:
# hi, i'm a string

# %%
with open('my_text_file.txt', mode='r', encoding='utf-8') as bdaca:
    mystrdata = bdaca.read()

# %%
mystrdata
# Out:
# "hi, i'm a string"

# %%
data = ['ik', 'jij', 'je', 'zij']
with open('pronouns.txt', mode='w', encoding='utf-8') as fo:
    for pronoun in data:
        fo.write(pronoun)
        fo.write('\n')

# %%
# !cat pronouns.txt
# Out:
# ik
#
# jij
#
# je
#
# zij

# %%
with open('pronouns.txt', mode='r', encoding='utf-8') as fi:
    my_new_data = [line.strip() for line in fi]
  #  my_new_data = []
  #  for line in fi:
  #      my_new_data.append(line.strip())
#print(data)

# %%
my_new_data
# Out:
# ['ik', 'jij', 'je', 'zij']

# %%
import pandas as pd

# %%
# !ls
# Out:
# .ipynb_checkpoints Untitled.ipynb     pronouns.txt
# API_example.ipynb  my_text_file.txt

# %%
PATH_TO_FILE = '/Users/anne/repos/teaching-bdaca-2425s2/teaching-bdaca/6ec-course/week01/covid.csv'

# %%
df = pd.read_csv(PATH_TO_FILE)

# %%
df.head()
# Out:
#              status_id            created_at      screen_name lang  \
# 0  1309535775109926912  2020-09-25T16:50:33Z  ghulamabbasshah   en
# 1  1309626010221129729  2020-09-25T22:49:07Z       GeoRebekah   en
# 2  1309578234007257088  2020-09-25T19:39:16Z     AlexBerenson   en
# 3  1309557875296083969  2020-09-25T18:18:22Z     AlexBerenson   en
# 4  1309643186827132929  2020-09-25T23:57:22Z        B52Malmet   en
#
#            location                                               text  \
# 0  Lahore, Pakistan  Secularism of #Gandhi and #Nehru in #India has...
# 1      Florida, USA  On the day @GovRonDeSantis rejects the experts...
# 2          New York  Updated @cgcgov figures: 66 children under 15 ...
# 3          New York  No mo ro in Flo: @govrondesantis proves again ...
# 4      New York, NY  Dr. Fauci warns the worst public health crisis...
#
#    retweet_count reply_to_screen_name
# 0           1203                  NaN
# 1           1146                  NaN
# ...
