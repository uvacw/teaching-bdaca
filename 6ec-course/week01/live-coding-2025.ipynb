# %%
print("hello world")
# Out:
# hello world

# %%
def uppercase_mystr(x):
    '''this function does and that...'''
    y = x.upper()
    return y

# %%
uppercase_mystr('This is an example')
# Out:
# 'THIS IS AN EXAMPLE'

# %%
my_first_list = ["one", "two", "three"]
my_second_list = ["four", "five"]

# %%
my_first_list.extend(my_second_list)

# %%
my_string = 'bike'

# %%
my_string.upper()
# Out:
# 'BIKE'

# %%
my_string
# Out:
# 'bike'

# %%
my_list = ['chenyue', 'sarah', 'annebel', 'hans']
#my_list.sort()
my_sorted_list = sorted(my_list)

# %%
my_sorted_list
# Out:
# ['annebel', 'chenyue', 'hans', 'sarah']

# %%
my_friends = ['alice', 'rebeca', 'denis']

for x in my_friends:
    print(f"My buddy {x} is {agedict[x]} years old")
# Out:
# My buddy alice is 18 years old
# My buddy rebeca is 20 years old
# My buddy denis is 99 years old

# %%
agedict = {'zeus': None, 
          'denis': 99, 
          'alice': 18, 
          'rebeca' : 20}


for k, v in agedict.items():
    print(f"{k.upper()} == key")
# Out:
# ZEUS == key
# DENIS == key
# ALICE == key
# REBECA == key

# %%
x = 55
my_list = [4, 99,5, 20]
        
def return_values(x):
    if x < 10 :
       # print(f"{x} is smaller than 10")
        return "SMALLER THAN 10"
    elif x > 20:
      #  print(f"{x} is larger than 20")
        return "LARGER THAN 20"
    else:
     #   print("nothing worked")
        return None

# %%
results = []

for x in my_list:
    results.append(return_values(x))

# %%
results
# Out:
# ['SMALLER THAN 10', 'LARGER THAN 20', 'SMALLER THAN 10', None]

# %%
x = ['5', 'aliijog', 10, 11]
my_results = []

def convert_to_int(x):
    try:
        return int(x)
    except:
        return None
    
for e in x:
    my_results.append(convert_to_int(e))

# %%
my_results
# Out:
# [5, None, 10, 11]

# %%
a = 1

while a <= 5:
    print(a)
    a += 1
    #a = a + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
import time

second = 5

while second > 0:
    print(second)
    time.sleep(1)
    second -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
my_values = [ 44, 1, 2, 7]

squared = []
for e in my_values:
    squared.append(e**2)
squared
# Out:
# [1936, 1, 4, 49]

# %%
squared = [e**2 for e in my_values if e < 40]

# %%
squared
# Out:
# [1, 4, 49]

# %%
def my_square_gen(x):
    y = x**2
    yield y

# %%
a = my_square_gen(6)
a

# %%
mynumber = [2,11,66]
squares = (number**2 for number in mynumber)

# %%
for i in squares:
    print(i)

# %%
ages = [22, 88, 34, 90]
names = ['alice', 'denis', 'sarah', 'kate']

# %%
for a, n in combined:
    print(a,n)
# Out:
# 22 alice
# 88 denis
# 34 sarah
# 90 kate

# %%
ages = [22, 88, 34, 90]
names = ['alice', 'denis', 'sarah', 'kate']

for age, name in zip(ages,names):
    print(age)
    print(name)
# Out:
# 22
# alice
# 88
# denis
# 34
# sarah
# 90
# kate

# %%
combined = dict(zip(names, ages))

# %%
type(combined)
# Out:
# dict

# %%
names = ['babara 069372930', 'sophie 0983239', 'wang 09282390']

my_dict = {}
for name in names:
   # print(name.split()[0])
   # print(name.split()[1])
    my_dict[name.split()[0]] = name.split()[1]
    
my_dict
# Out:
# {'babara': '069372930', 'sophie': '0983239', 'wang': '09282390'}

# %%
my_dict = {}
words = ['data', 'python', 'analyis', 'nlp', 'data', 'data']

for word in words:
    if word in my_dict:
        my_dict[word] += 1
    else:
        my_dict[word] = 1

# %%
from collections import defaultdict

my_dict = defaultdict(int)

words = ['data', 'python', 'analyis', 'nlp', 'data', 'data']

for word in words:
    my_dict[word]+=1

# %%
my_dict
# Out:
# defaultdict(int, {'data': 3, 'python': 1, 'analyis': 1, 'nlp': 1})
