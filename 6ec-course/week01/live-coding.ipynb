# %%
firstname = 'alice'

# %%
"alice"

# %%
firstname

# %%
"firstname"

# %%
int("5") * 3

# %%
my_list = ['alice', 55, 'hello', 44.3]

# %%
my_dict ={}
my_dict['alice'] = 55
my_dict['thomas'] = {'phonenumber': '093060'}

# %%
for k, v my_dict.items():

# %%
print(f"The age of Thomas is: {my_dict['thomas']}" )

#print("the age of thomas is:")
#print(my_dict['thomas'])
#print( my_list[3] )

# %%
my_list = ['alice', 'alice', 'sarah', 'anne', 'pieter', 'chenyue', 'joyce']
#my_list[2:-1]

# %%
set(my_list)

# %%
names = ['alice','chenyue', 'sarah', 'anne', 'pieter','chenyue', 'chenyue', 'alice', 'joyce']

my_dict = defaultdict(int)
print(my_dict)

for name in names:
    print(f"this is the name in the current loop: {name}")
    my_dict[name]+=1

# %%
my_dict

# %%
names = ['alice','chenyue', 'sarah', 'anne', 'pieter','chenyue', 'chenyue', 'alice', 'joyce']

# %%
from collections import defaultdict

# %%
my_dict = defaultdict(str)
my_dict['alice'] = 55
my_dict['sarah'] = 22
my_dict['pieter']
my_dict

# %%
'//'. join(" Good Morning  ".split())

# %%
x = [2,6,9,3]
len(x)

# %%
my_first_list = ['good', 'morning']
my_second_list = ['students', '!'] 

my_first_list.extend(my_second_list)
my_first_list

# %%
uppercased_names  = []
for name in names:
   # print(name.upper())
    uppercased_names.append(name.upper() )

# %%
uppercased_names

# %%
import sys
sys.version

# %% [markdown]
# ### Good morning!
#
# i will use this to illustrate a `print()` function

# %%
print('hello')

# %%
agedict = {
    'Zeus': None, 
    'Denis' : 96, 
    'Alice': 18, 
    'Rebecca' : 20
}

myfriends = ['Alice', 'Denis', 'Rebecca']

for friend in myfriends:
    print(f"my buddy {friend} is {agedict[friend]} years old")

# %%
for index in enumerate(myfriends):
    print(index)

# %%
friend

# %%
mylist = ['Alice', 'Denis', 'Rebecca', 'Juno', 'Ezra', 'Wim', 'Marieke']
mylist[-0]

# %%
my_dict = {"Alice" : 66, "Denis" : 17, "Juno" : 4 }

# %%
for k, v in my_dict.items():
    print(v)

# %%
my_list = ["5", 4, "7", "8", "weiojgeij", 5, 7]

converted_values = []
errors = []

for e in my_list:
    print(f"trying to convert {e}")
    try: 
        converted_values.append(int(e))
        print("Yes that works!!")
    except: 
        print("ERROR")
        errors=+1

# %%
errors

# %%
converted_values

# %%
len(my_list) == len(converted_values)

# %%
def square_generator(listofnumbers):
    yield [e**2 for e in listofnumbers]

my_list = [4,9,11,20] 
mygen = square_generator(my_list)
mygen

# %%
names = ['anne', 'sarah', 'chenyue', ' pieter']
ages = [39, 44, 51]
country = ['Netherlands', 'Germany', 'China']

len(names) == len(ages)
names_ages = zip(names, ages, country)

# %%
next(names_ages)
# Out:
# ('anne', 39, 'Netherlands')

# %%
for name, age, country in names_ages: 
    print(name, age, country)

# %%
names = ['anne', 'sarah', 'chenyue']
my_results = []
for name in names:
    my_results.append(name.upper())

# %%
name_upper = [name.upper() for name in names]
